# %%
import pandas as pd
import numpy as np
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
# df_test = pd.read_csv("Groceries data test.csv")
df = pd.read_csv("Groceries data train.csv")

# %%
print("Data shape:", df.shape)
print("\nFirst few rows of the dataset:")
df.head()
# Out:
# Data shape: (27000, 7)
#
# First few rows of the dataset:
#    Member_number        Date  itemDescription  year  month  day  day_of_week
# 0           3021  30/01/2015      frankfurter  2015      1   30            4
# 1           1292  24/10/2015             pork  2015     10   24            5
# 2           4206   4/04/2014  root vegetables  2014      4    4            4
# 3           4369  25/08/2015           onions  2015      8   25            1
# 4           1522   1/07/2014          waffles  2014      7    1            1

# %%
# checking for null or missing value
print("\nMissing values in each column:")
df_missing = pd.DataFrame((round(100 * (df.isnull().sum() / len(df.index)), 2)), columns=['missing'])
df_missing
# Out:
# Missing values in each column:
#                  missing
# Member_number        0.0
# Date                 0.0
# itemDescription      0.0
# year                 0.0
# month                0.0
# day                  0.0
# day_of_week          0.0

# %%
df['itemDescription'].unique()
# Out:
# array(['frankfurter', 'pork', 'root vegetables', 'onions', 'waffles',
#        'cereals', 'yogurt', 'sausage', 'rolls/buns', 'chocolate',
#        'whipped/sour cream', 'butter', 'curd', 'frozen meals',
#        'whole milk', 'tropical fruit', 'sugar', 'specialty cheese',
#        'other vegetables', 'fruit/vegetable juice', 'misc. beverages',
#        'frozen vegetables', 'spices', 'coffee', 'cream cheese ',
#        'red/blush wine', 'dessert', 'long life bakery product',
#        'domestic eggs', 'abrasive cleaner', 'berries',
#        'liquor (appetizer)', 'semi-finished bread', 'newspapers',
#        'beverages', 'beef', 'female sanitary products', 'salt', 'soda',
#        'sauces', 'oil', 'snack products', 'brown bread',
#        'hygiene articles', 'artif. sweetener', 'bottled beer',
#        'canned beer', 'hamburger meat', 'liver loaf', 'soups',
#        'pip fruit', 'hard cheese', 'shopping bags', 'canned vegetables',
#        'napkins', 'citrus fruit', 'margarine', 'pasta', 'salty snack',
#        'candles', 'cat food', 'meat', 'candy', 'condensed milk',
#        'UHT-milk', 'chewing gum', 'chicken', 'soft cheese', 'pastry',
#        'specialty chocolate', 'packaged fruit/vegetables',
#        'bottled water', 'cling film/bags', 'processed cheese', 'mustard',
#        'seasonal products', 'ham', 'herbs', 'white bread', 'mayonnaise',
#        'dental care', 'grapes', 'fish', 'nut snack', 'pickled vegetables',
#        'butter milk', 'finished products', 'dishes', 'frozen fish',
#        'dish cleaner', 'frozen dessert', 'flower (seeds)',
#        'male cosmetics', 'white wine', 'frozen chicken', 'instant coffee',
#        'pot plants', 'nuts/prunes', 'rice', 'turkey', 'ice cream',
#        'sliced cheese', 'canned fruit', 'popcorn', 'baking powder',
#        'kitchen towels', 'specialty vegetables', 'cake bar',
#        'specialty bar', 'flour', 'softener', 'cleaner', 'soap', 'vinegar',
#        'roll products ', 'pudding powder', 'pet care', 'whisky',
#        'zwieback', 'sparkling wine', 'dog food', 'liquor', 'photo/film',
#        'jam', 'chocolate marshmallow', 'curd cheese', 'spread cheese',
#        'Instant food products', 'sweet spreads', 'brandy', 'canned fish',
#        'baby cosmetics', 'frozen potato products', 'ketchup',
#        'cooking chocolate', 'hair spray', 'honey', 'light bulbs',
#        'specialty fat', 'cream', 'flower soil/fertilizer', 'ready soups',
#        'tea', 'salad dressing', 'cookware', 'toilet cleaner',
#        'meat spreads', 'potato products', 'detergent', 'liqueur',
#        'decalcifier', 'cocoa drinks', 'tidbits', 'rum', 'prosecco',
#        'organic products', 'syrup', 'organic sausage',
#        'house keeping products', 'frozen fruits', 'bathroom cleaner',
#        'skin care', 'bags', 'rubbing alcohol', 'make up remover',
#        'preservation products', 'kitchen utensil'], dtype=object)

# %%
# Clean itemDescription
df['itemDescription'] = df['itemDescription'].str.strip()

# %%
basket_df = df.groupby(['Member_number', 'Date'])['itemDescription'].apply(list).reset_index()
transactions = basket_df['itemDescription'].tolist()

# %%
basket_df.head()
# Out:
#    Member_number        Date                 itemDescription
# 0           1000  15/03/2015               [sausage, yogurt]
# 1           1000  24/06/2014                        [pastry]
# 2           1000  24/07/2015  [misc. beverages, canned beer]
# 3           1000  25/11/2015                       [sausage]
# 4           1000  27/05/2015      [soda, pickled vegetables]

# %%
transactions[0]
# Out:
# ['sausage', 'yogurt']

# %%
# Top 20 items
item_counts = Counter([item for sublist in transactions for item in sublist])
print(item_counts.most_common(20))
# Out:
# [('whole milk', 1709), ('other vegetables', 1320), ('rolls/buns', 1197), ('soda', 1060), ('yogurt', 928), ('root vegetables', 733), ('tropical fruit', 683), ('bottled water', 666), ('sausage', 637), ('citrus fruit', 560), ('pastry', 558), ('pip fruit', 512), ('shopping bags', 499), ('bottled beer', 493), ('canned beer', 488), ('whipped/sour cream', 470), ('brown bread', 415), ('newspapers', 414), ('frankfurter', 411), ('domestic eggs', 400)]

# %%
# 3. Transaction Encoding for Apriori
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# %%
df_encoded.head()
# Out:
#    Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                  False     False             False             False
# 1                  False     False             False             False
# 2                  False     False             False             False
# 3                  False     False             False             False
# 4                  False     False             False             False
#
#    baby cosmetics   bags  baking powder  bathroom cleaner   beef  berries  \
# 0           False  False          False             False  False    False
# 1           False  False          False             False  False    False
# 2           False  False          False             False  False    False
# 3           False  False          False             False  False    False
# 4           False  False          False             False  False    False
#
#    ...  turkey  vinegar  waffles  whipped/sour cream  whisky  white bread  \
# 0  ...   False    False    False               False   False        False
# 1  ...   False    False    False               False   False        False
# 2  ...   False    False    False               False   False        False
# 3  ...   False    False    False               False   False        False
# 4  ...   False    False    False               False   False        False
#
#    white wine  whole milk  yogurt  zwieback
# 0       False       False    True     False
# 1       False       False   False     False
# 2       False       False   False     False
# 3       False       False   False     False
# 4       False       False   False     False
#
# [5 rows x 167 columns]

# %%
# 4. Frequent Itemset Mining with Apriori
# Parameter tuning
# min_support_values = [0.01, 0.02, 0.03, 0.05]
min_support_values = [0.002,0.003,0.004, 0.005, 0.008]
results = {}

for min_support in min_support_values:
    frequent_itemsets = apriori(df_encoded, min_support=min_support, use_colnames=True)
    results[min_support] = frequent_itemsets
    print(f"\nFrequent itemsets for min_support={min_support}:")
    # print(frequent_itemsets.sort_values('support', ascending=False).head(20))
    print(frequent_itemsets.sort_values('support', ascending=False))
# Out:
# Frequent itemsets for min_support=0.002:
#       support                         itemsets
# 112  0.118049                     (whole milk)
# 68   0.092799               (other vegetables)
# 83   0.083519                     (rolls/buns)
# 93   0.074095                           (soda)
# 113  0.064312                         (yogurt)
# ..        ...                              ...
# 135  0.002014             (citrus fruit, soda)
# 129  0.002014  (canned beer, other vegetables)
# 126  0.002014       (butter, other vegetables)
# 161  0.002014                   (pastry, soda)
# 95   0.002014                       (softener)
#
# [191 rows x 2 columns]
#
# Frequent itemsets for min_support=0.003:
#       support                   itemsets
# 97   0.118049               (whole milk)
# 61   0.092799         (other vegetables)
# 74   0.083519               (rolls/buns)
# 83   0.074095                     (soda)
# 98   0.064312                   (yogurt)
# ..        ...                        ...
# 103  0.003021  (canned beer, whole milk)
# 99   0.003021                 (zwieback)
# 128  0.003021             (soda, yogurt)
# 32   0.003021        (finished products)
# 0    0.003021    (Instant food products)
#
# [131 rows x 2 columns]
#
# Frequent itemsets for min_support=0.004:
#      support                     itemsets
# 83  0.118049                 (whole milk)
# 52  0.092799           (other vegetables)
# 63  0.083519                 (rolls/buns)
# 72  0.074095                       (soda)
# 84  0.064312                     (yogurt)
# ..       ...                          ...
# 85  0.004316  (bottled water, whole milk)
# 10  0.004316                   (cake bar)
# 65  0.004172                       (salt)
# 20  0.004172            (cling film/bags)
# 89  0.004100   (other vegetables, yogurt)
#
# [96 rows x 2 columns]
#
# Frequent itemsets for min_support=0.005:
#      support                        itemsets
# 75  0.118049                    (whole milk)
# 47  0.092799              (other vegetables)
# 57  0.083519                    (rolls/buns)
# 65  0.074095                          (soda)
# 76  0.064312                        (yogurt)
# ..       ...                             ...
# 27  0.005611                   (frozen fish)
# 78  0.005467        (soda, other vegetables)
# 38  0.005467                        (liquor)
# 81  0.005251           (sausage, whole milk)
# 77  0.005036  (rolls/buns, other vegetables)
#
# [84 rows x 2 columns]
#
# Frequent itemsets for min_support=0.008:
#      support            itemsets
# 61  0.118049        (whole milk)
# 40  0.092799  (other vegetables)
# 46  0.083519        (rolls/buns)
# 52  0.074095              (soda)
# 62  0.064312            (yogurt)
# ..       ...                 ...
# 12  0.008704       (chewing gum)
# 60  0.008632        (white wine)
# 45  0.008273    (red/blush wine)
# 44  0.008201  (processed cheese)
# 29  0.008057             (herbs)
#
# [63 rows x 2 columns]

# %%
# Show frequent itemsets with more than one item
for min_support in min_support_values:
    fi = results[min_support]
    multi_itemsets = fi[fi['itemsets'].apply(lambda x: len(x) > 1)]
    print(f"\nFrequent itemsets with more than one item for min_support={min_support}:")
    print(multi_itemsets)
# Out:
# Frequent itemsets with more than one item for min_support=0.002:
#       support                          itemsets
# 115  0.002446                (whole milk, beef)
# 116  0.002518  (bottled beer, other vegetables)
# 117  0.002302        (rolls/buns, bottled beer)
# 118  0.003741        (whole milk, bottled beer)
# 119  0.002014            (bottled beer, yogurt)
# ..        ...                               ...
# 186  0.003021                    (soda, yogurt)
# 187  0.003741      (tropical fruit, whole milk)
# 188  0.002014          (tropical fruit, yogurt)
# 189  0.002518  (whole milk, whipped/sour cream)
# 190  0.006546              (whole milk, yogurt)
#
# [76 rows x 2 columns]
#
# Frequent itemsets with more than one item for min_support=0.003:
#       support                             itemsets
# 100  0.003741           (whole milk, bottled beer)
# 101  0.003237          (bottled water, rolls/buns)
# 102  0.004316          (bottled water, whole milk)
# 103  0.003021            (canned beer, whole milk)
# 104  0.003381           (citrus fruit, whole milk)
# 105  0.003093          (domestic eggs, whole milk)
# 106  0.003093      (frankfurter, other vegetables)
# 107  0.003237            (frankfurter, whole milk)
# 108  0.005036       (rolls/buns, other vegetables)
# 109  0.003093  (root vegetables, other vegetables)
# 110  0.005467             (soda, other vegetables)
# 111  0.003093   (tropical fruit, other vegetables)
# 112  0.006978       (whole milk, other vegetables)
# 113  0.004100           (other vegetables, yogurt)
# 114  0.003165                 (pastry, whole milk)
# 115  0.003093              (rolls/buns, pip fruit)
# 116  0.003381              (pip fruit, whole milk)
# 117  0.003381        (root vegetables, rolls/buns)
# 118  0.003021                (sausage, rolls/buns)
# 119  0.004388                   (soda, rolls/buns)
# 120  0.007913             (rolls/buns, whole milk)
# 121  0.004460                 (rolls/buns, yogurt)
# 122  0.003309        (root vegetables, whole milk)
# 123  0.003309                      (sausage, soda)
# 124  0.005251                (sausage, whole milk)
# 125  0.003237                    (sausage, yogurt)
# 126  0.003597          (whole milk, shopping bags)
# 127  0.005971                   (soda, whole milk)
# 128  0.003021                       (soda, yogurt)
# 129  0.003741         (tropical fruit, whole milk)
# 130  0.006546                 (whole milk, yogurt)
#
# Frequent itemsets with more than one item for min_support=0.004:
#      support                        itemsets
# 85  0.004316     (bottled water, whole milk)
# 86  0.005036  (rolls/buns, other vegetables)
# 87  0.005467        (soda, other vegetables)
# 88  0.006978  (whole milk, other vegetables)
# 89  0.004100      (other vegetables, yogurt)
# 90  0.004388              (soda, rolls/buns)
# 91  0.007913        (rolls/buns, whole milk)
# 92  0.004460            (rolls/buns, yogurt)
# 93  0.005251           (sausage, whole milk)
# 94  0.005971              (soda, whole milk)
# 95  0.006546            (whole milk, yogurt)
#
# Frequent itemsets with more than one item for min_support=0.005:
#      support                        itemsets
# 77  0.005036  (rolls/buns, other vegetables)
# 78  0.005467        (soda, other vegetables)
# 79  0.006978  (whole milk, other vegetables)
# 80  0.007913        (rolls/buns, whole milk)
# 81  0.005251           (sausage, whole milk)
# 82  0.005971              (soda, whole milk)
# 83  0.006546            (whole milk, yogurt)
#
# Frequent itemsets with more than one item for min_support=0.008:
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []

# %%
chosen_support = 0.002
frequent_itemsets = results[chosen_support]

# 5. Association Rule Mining
min_confidence_values = [0.01, 0.05, 0.08, 0.09, 0.1]
for min_conf in min_confidence_values:
    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_conf)
    rules = rules.sort_values('lift', ascending=False)
    print(f"\nAssociation Rules for min_confidence={min_conf}:")
    print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].head(20))

# Choose a min_confidence for visualization (e.g., 0.2)
chosen_conf = 0.08
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=chosen_conf)
# Out:
# Association Rules for min_confidence=0.01:
#             antecedents         consequents   support  confidence      lift
# 56        (frankfurter)  (other vegetables)  0.003093    0.107232  1.155528
# 57   (other vegetables)       (frankfurter)  0.003093    0.033333  1.155528
# 130           (sausage)            (yogurt)  0.003237    0.071542  1.112424
# 131            (yogurt)           (sausage)  0.003237    0.050336  1.112424
# 132              (soda)     (shopping bags)  0.002877    0.038835  1.099480
# 133     (shopping bags)              (soda)  0.002877    0.081466  1.099480
# 25             (butter)              (soda)  0.002086    0.076923  1.038163
# 24               (soda)            (butter)  0.002086    0.028155  1.038163
# 96         (rolls/buns)         (pip fruit)  0.003093    0.037037  1.015487
# 97          (pip fruit)        (rolls/buns)  0.003093    0.084813  1.015487
# 44       (citrus fruit)            (yogurt)  0.002590    0.065099  1.012246
# 45             (yogurt)      (citrus fruit)  0.002590    0.040268  1.012246
# 126           (sausage)              (soda)  0.003309    0.073132  0.986997
# 127              (soda)           (sausage)  0.003309    0.044660  0.986997
# 129        (whole milk)           (sausage)  0.005251    0.044485  0.983127
# 128           (sausage)        (whole milk)  0.005251    0.116057  0.983127
# 33             (yogurt)       (canned beer)  0.002158    0.033557  0.971826
# 32        (canned beer)            (yogurt)  0.002158    0.062500  0.971826
# 108        (rolls/buns)     (shopping bags)  0.002806    0.033592  0.951036
# 109     (shopping bags)        (rolls/buns)  0.002806    0.079430  0.951036
#
# Association Rules for min_confidence=0.05:
#         antecedents         consequents   support  confidence      lift
# 28    (frankfurter)  (other vegetables)  0.003093    0.107232  1.155528
# 68        (sausage)            (yogurt)  0.003237    0.071542  1.112424
# 69         (yogurt)           (sausage)  0.003237    0.050336  1.112424
# 70  (shopping bags)              (soda)  0.002877    0.081466  1.099480
# 12         (butter)              (soda)  0.002086    0.076923  1.038163
# 51      (pip fruit)        (rolls/buns)  0.003093    0.084813  1.015487
# 22   (citrus fruit)            (yogurt)  0.002590    0.065099  1.012246
# 66        (sausage)              (soda)  0.003309    0.073132  0.986997
# 67        (sausage)        (whole milk)  0.005251    0.116057  0.983127
# 16    (canned beer)            (yogurt)  0.002158    0.062500  0.971826
# 57  (shopping bags)        (rolls/buns)  0.002806    0.079430  0.951036
# 29    (frankfurter)        (whole milk)  0.003237    0.112219  0.950617
# 35           (pork)  (other vegetables)  0.002374    0.086842  0.935808
# 27  (domestic eggs)        (whole milk)  0.003093    0.109137  0.924506
# 52      (pip fruit)              (soda)  0.002446    0.067061  0.905065
# 3    (bottled beer)        (whole milk)  0.003741    0.106557  0.902653
# 24           (curd)  (other vegetables)  0.002158    0.082873  0.893036
# 4    (bottled beer)            (yogurt)  0.002014    0.057377  0.892168
# 13         (butter)        (whole milk)  0.002806    0.103448  0.876316
# 26  (domestic eggs)  (other vegetables)  0.002302    0.081218  0.875206
#
# Association Rules for min_confidence=0.08:
#                 antecedents         consequents   support  confidence  \
# 12            (frankfurter)  (other vegetables)  0.003093    0.107232
# 23          (shopping bags)              (soda)  0.002877    0.081466
# 18              (pip fruit)        (rolls/buns)  0.003093    0.084813
# 22                (sausage)        (whole milk)  0.005251    0.116057
# 13            (frankfurter)        (whole milk)  0.003237    0.112219
# 17                   (pork)  (other vegetables)  0.002374    0.086842
# 11          (domestic eggs)        (whole milk)  0.003093    0.109137
# 1            (bottled beer)        (whole milk)  0.003741    0.106557
# 8                    (curd)  (other vegetables)  0.002158    0.082873
# 4                  (butter)        (whole milk)  0.002806    0.103448
# 10          (domestic eggs)  (other vegetables)  0.002302    0.081218
# 24          (shopping bags)        (whole milk)  0.003597    0.101833
# 26                 (yogurt)        (whole milk)  0.006546    0.101790
# 15  (fruit/vegetable juice)        (whole milk)  0.002590    0.099723
# 14      (frozen vegetables)        (whole milk)  0.002158    0.099668
# 20                   (pork)        (whole milk)  0.002662    0.097368
# 6                 (chicken)        (whole milk)  0.002014    0.096220
# 21             (rolls/buns)        (whole milk)  0.007913    0.094746
# 16             (newspapers)        (whole milk)  0.002734    0.093827
# 19              (pip fruit)        (whole milk)  0.003381    0.092702
#
#         lift
# 12  1.155528
# 23  1.099480
# 18  1.015487
# 22  0.983127
# 13  0.950617
# 17  0.935808
# 11  0.924506
# 1   0.902653
# 8   0.893036
# 4   0.876316
# 10  0.875206
# 24  0.862633
# 26  0.862266
# 15  0.844759
# 14  0.844291
# 20  0.824813
# 6   0.815084
# 21  0.802598
# 16  0.794815
# 19  0.785285
#
# Association Rules for min_confidence=0.09:
#                 antecedents         consequents   support  confidence  \
# 6             (frankfurter)  (other vegetables)  0.003093    0.107232
# 14                (sausage)        (whole milk)  0.005251    0.116057
# 7             (frankfurter)        (whole milk)  0.003237    0.112219
# 5           (domestic eggs)        (whole milk)  0.003093    0.109137
# 1            (bottled beer)        (whole milk)  0.003741    0.106557
# 3                  (butter)        (whole milk)  0.002806    0.103448
# 15          (shopping bags)        (whole milk)  0.003597    0.101833
# 16                 (yogurt)        (whole milk)  0.006546    0.101790
# 9   (fruit/vegetable juice)        (whole milk)  0.002590    0.099723
# 8       (frozen vegetables)        (whole milk)  0.002158    0.099668
# 12                   (pork)        (whole milk)  0.002662    0.097368
# 4                 (chicken)        (whole milk)  0.002014    0.096220
# 13             (rolls/buns)        (whole milk)  0.007913    0.094746
# 10             (newspapers)        (whole milk)  0.002734    0.093827
# 11              (pip fruit)        (whole milk)  0.003381    0.092702
# 0                    (beef)        (whole milk)  0.002446    0.092643
# 2           (bottled water)        (whole milk)  0.004316    0.091603
#
#         lift
# 6   1.155528
# 14  0.983127
# 7   0.950617
# 5   0.924506
# 1   0.902653
# 3   0.876316
# 15  0.862633
# 16  0.862266
# 9   0.844759
# 8   0.844291
# 12  0.824813
# 4   0.815084
# 13  0.802598
# 10  0.794815
# 11  0.785285
# 0   0.784784
# 2   0.775974
#
# Association Rules for min_confidence=0.1:
#        antecedents         consequents   support  confidence      lift
# 3    (frankfurter)  (other vegetables)  0.003093    0.107232  1.155528
# 5        (sausage)        (whole milk)  0.005251    0.116057  0.983127
# 4    (frankfurter)        (whole milk)  0.003237    0.112219  0.950617
# 2  (domestic eggs)        (whole milk)  0.003093    0.109137  0.924506
# 0   (bottled beer)        (whole milk)  0.003741    0.106557  0.902653
# 1         (butter)        (whole milk)  0.002806    0.103448  0.876316
# 6  (shopping bags)        (whole milk)  0.003597    0.101833  0.862633
# 7         (yogurt)        (whole milk)  0.006546    0.101790  0.862266

# %%
frequent_itemsets = apriori(df_encoded, min_support=0.003, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.08)
rules = rules.sort_values(['confidence','lift'],ascending=[False,False])
print(rules)
# Out:
#         antecedents         consequents  antecedent support  \
# 10        (sausage)        (whole milk)            0.045249
# 6     (frankfurter)        (whole milk)            0.028847
# 4   (domestic eggs)        (whole milk)            0.028343
# 5     (frankfurter)  (other vegetables)            0.028847
# 0    (bottled beer)        (whole milk)            0.035105
# 11  (shopping bags)        (whole milk)            0.035321
# 13         (yogurt)        (whole milk)            0.064312
# 9      (rolls/buns)        (whole milk)            0.083519
# 8       (pip fruit)        (whole milk)            0.036472
# 1   (bottled water)        (whole milk)            0.047119
# 2     (canned beer)        (whole milk)            0.034530
# 3    (citrus fruit)        (whole milk)            0.039781
# 7       (pip fruit)        (rolls/buns)            0.036472
# 12           (soda)        (whole milk)            0.074095
#
#     consequent support   support  confidence      lift  representativity  \
# 10            0.118049  0.005251    0.116057  0.983127               1.0
# 6             0.118049  0.003237    0.112219  0.950617               1.0
# 4             0.118049  0.003093    0.109137  0.924506               1.0
# 5             0.092799  0.003093    0.107232  1.155528               1.0
# 0             0.118049  0.003741    0.106557  0.902653               1.0
# 11            0.118049  0.003597    0.101833  0.862633               1.0
# 13            0.118049  0.006546    0.101790  0.862266               1.0
# 9             0.118049  0.007913    0.094746  0.802598               1.0
# 8             0.118049  0.003381    0.092702  0.785285               1.0
# 1             0.118049  0.004316    0.091603  0.775974               1.0
# 2             0.118049  0.003021    0.087500  0.741217               1.0
# 3             0.118049  0.003381    0.084991  0.719963               1.0
# 7             0.083519  0.003093    0.084813  1.015487               1.0
# 12            0.118049  0.005971    0.080583  0.682619               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 10 -0.000090    0.997747      -0.017658  0.033227  -0.002258    0.080271
# 6  -0.000168    0.993434      -0.050775  0.022534  -0.006610    0.069821
# 4  -0.000253    0.989996      -0.077526  0.021586  -0.010105    0.067670
# 5   0.000416    1.016166       0.138593  0.026092   0.015909    0.070283
# 0  -0.000403    0.987138      -0.100532  0.025036  -0.013030    0.069123
# 11 -0.000573    0.981945      -0.141684  0.024015  -0.018387    0.066151
# 13 -0.001046    0.981898      -0.145820  0.037234  -0.018436    0.078622
# 9  -0.001946    0.974258      -0.211585  0.040862  -0.026422    0.080889
# 8  -0.000924    0.972063      -0.221046  0.022370  -0.028740    0.060672
# 1  -0.001246    0.970887      -0.232527  0.026834  -0.029986    0.064083
# 2  -0.001055    0.966522      -0.265580  0.020202  -0.034638    0.056547
# 3  -0.001315    0.963871      -0.288294  0.021891  -0.037483    0.056816
# 7   0.000047    1.001413       0.015828  0.026462   0.001411    0.060925
# 12 -0.002776    0.959250      -0.334289  0.032071  -0.042481    0.065581

# %% [markdown]
# Using min_support = 0.003 and min_confidence = 0.1, we identified 62 association rules. The strongest rule, (frankfurter) → (other vegetables), has a confidence of 10.7% and a lift of 1.15, indicating that customers who buy frankfurters are more likely to also buy other vegetables. Most rules involve “whole milk” or “other vegetables”, reflecting their popularity. While most lifts are modest, these rules provide actionable insights for product placement and cross-selling.
#
# Support: Most rules have support just above 0.003 (0.3%), meaning they occur in at least ~81 baskets out of 27,000. This is reasonable for actionable but not too rare patterns.
#
# Confidence: All rules have confidence above 10% (your chosen threshold), meaning the consequent appears at least 10% of the time when the antecedent is present.
#
# Lift: Most lift values are between 0.9 and 1.15. A lift > 1 means the rule is better than random; only a few rules (notably (frankfurter) → (other vegetables)) exceed 1.
#
# Other metrics (leverage, conviction, etc.): Most are close to zero, indicating weak but not spurious associations.

# %%
# Add additional metrics (e.g., coverage, coverage ratio)
rules['coverage'] = rules['antecedents'].apply(
    lambda x: frequent_itemsets[frequent_itemsets['itemsets'] == x]['support'].values[0]
)
rules['zhang_metric'] = (rules['confidence'] - rules['consequent support']) / (1 - rules['consequent support'])

# --------------------------------------------
# 2. Display Top Rules by Different Metrics
# --------------------------------------------
def display_top_rules(rules, metric='lift', top_n=5):
    return rules.sort_values(metric, ascending=False).head(top_n)

print("\nTop 5 Rules by Lift:")
display(display_top_rules(rules, 'lift'))

print("\nTop 5 Rules by Confidence:")
display(display_top_rules(rules, 'confidence'))

print("\nTop 5 Rules by Support:")
display(display_top_rules(rules, 'support'))

# --------------------------------------------
# 3. Visualize Rule Quality
# --------------------------------------------
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x='confidence', 
    y='lift', 
    size='support', 
    hue='conviction', 
    data=rules,
    alpha=0.7,
    palette='viridis'
)
plt.title('Association Rules: Lift vs Confidence')
plt.xlabel('Confidence')
plt.ylabel('Lift')
plt.axhline(1, linestyle='--', color='red')  # Lift=1 baseline
plt.show()

# --------------------------------------------
# 4. Filter and Interpret Actionable Rules
# --------------------------------------------
# Filter rules with lift
actionable_rules = rules.sort_values('lift', ascending=False)

print("\nActionable Rules:")
display(actionable_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# Top 5 Rules by Lift:
#         antecedents         consequents  antecedent support  \
# 5     (frankfurter)  (other vegetables)            0.028847
# 7       (pip fruit)        (rolls/buns)            0.036472
# 10        (sausage)        (whole milk)            0.045249
# 6     (frankfurter)        (whole milk)            0.028847
# 4   (domestic eggs)        (whole milk)            0.028343
#
#     consequent support   support  confidence      lift  representativity  \
# 5             0.092799  0.003093    0.107232  1.155528               1.0
# 7             0.083519  0.003093    0.084813  1.015487               1.0
# 10            0.118049  0.005251    0.116057  0.983127               1.0
# 6             0.118049  0.003237    0.112219  0.950617               1.0
# 4             0.118049  0.003093    0.109137  0.924506               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski  \
# 5   0.000416    1.016166       0.138593  0.026092   0.015909    0.070283
# 7   0.000047    1.001413       0.015828  0.026462   0.001411    0.060925
# 10 -0.000090    0.997747      -0.017658  0.033227  -0.002258    0.080271
# 6  -0.000168    0.993434      -0.050775  0.022534  -0.006610    0.069821
# 4  -0.000253    0.989996      -0.077526  0.021586  -0.010105    0.067670
#
#     coverage  zhang_metric
# 5   0.028847      0.015909
# 7   0.036472      0.001411
# 10  0.045249     -0.002258
# 6   0.028847     -0.006610
# 4   0.028343     -0.010105
# Top 5 Rules by Confidence:
#         antecedents         consequents  antecedent support  \
# 10        (sausage)        (whole milk)            0.045249
# 6     (frankfurter)        (whole milk)            0.028847
# 4   (domestic eggs)        (whole milk)            0.028343
# 5     (frankfurter)  (other vegetables)            0.028847
# 0    (bottled beer)        (whole milk)            0.035105
#
#     consequent support   support  confidence      lift  representativity  \
# 10            0.118049  0.005251    0.116057  0.983127               1.0
# 6             0.118049  0.003237    0.112219  0.950617               1.0
# 4             0.118049  0.003093    0.109137  0.924506               1.0
# 5             0.092799  0.003093    0.107232  1.155528               1.0
# 0             0.118049  0.003741    0.106557  0.902653               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski  \
# 10 -0.000090    0.997747      -0.017658  0.033227  -0.002258    0.080271
# 6  -0.000168    0.993434      -0.050775  0.022534  -0.006610    0.069821
# 4  -0.000253    0.989996      -0.077526  0.021586  -0.010105    0.067670
# 5   0.000416    1.016166       0.138593  0.026092   0.015909    0.070283
# 0  -0.000403    0.987138      -0.100532  0.025036  -0.013030    0.069123
#
#     coverage  zhang_metric
# 10  0.045249     -0.002258
# 6   0.028847     -0.006610
# 4   0.028343     -0.010105
# 5   0.028847      0.015909
# 0   0.035105     -0.013030
# Top 5 Rules by Support:
#         antecedents   consequents  antecedent support  consequent support  \
# 9      (rolls/buns)  (whole milk)            0.083519            0.118049
# 13         (yogurt)  (whole milk)            0.064312            0.118049
# 12           (soda)  (whole milk)            0.074095            0.118049
# 10        (sausage)  (whole milk)            0.045249            0.118049
# 1   (bottled water)  (whole milk)            0.047119            0.118049
#
#      support  confidence      lift  representativity  leverage  conviction  \
# 9   0.007913    0.094746  0.802598               1.0 -0.001946    0.974258
# 13  0.006546    0.101790  0.862266               1.0 -0.001046    0.981898
# 12  0.005971    0.080583  0.682619               1.0 -0.002776    0.959250
# 10  0.005251    0.116057  0.983127               1.0 -0.000090    0.997747
# 1   0.004316    0.091603  0.775974               1.0 -0.001246    0.970887
#
#     zhangs_metric   jaccard  certainty  kulczynski  coverage  zhang_metric
# 9       -0.211585  0.040862  -0.026422    0.080889  0.083519     -0.026422
# 13      -0.145820  0.037234  -0.018436    0.078622  0.064312     -0.018436
# 12      -0.334289  0.032071  -0.042481    0.065581  0.074095     -0.042481
# 10      -0.017658  0.033227  -0.002258    0.080271  0.045249     -0.002258
# 1       -0.232527  0.026834  -0.029986    0.064083  0.047119     -0.029986
# Actionable Rules:
#         antecedents         consequents   support  confidence      lift
# 5     (frankfurter)  (other vegetables)  0.003093    0.107232  1.155528
# 7       (pip fruit)        (rolls/buns)  0.003093    0.084813  1.015487
# 10        (sausage)        (whole milk)  0.005251    0.116057  0.983127
# 6     (frankfurter)        (whole milk)  0.003237    0.112219  0.950617
# 4   (domestic eggs)        (whole milk)  0.003093    0.109137  0.924506
# 0    (bottled beer)        (whole milk)  0.003741    0.106557  0.902653
# 11  (shopping bags)        (whole milk)  0.003597    0.101833  0.862633
# 13         (yogurt)        (whole milk)  0.006546    0.101790  0.862266
# 9      (rolls/buns)        (whole milk)  0.007913    0.094746  0.802598
# 8       (pip fruit)        (whole milk)  0.003381    0.092702  0.785285
# 1   (bottled water)        (whole milk)  0.004316    0.091603  0.775974
# 2     (canned beer)        (whole milk)  0.003021    0.087500  0.741217
# 3    (citrus fruit)        (whole milk)  0.003381    0.084991  0.719963
# 12           (soda)        (whole milk)  0.005971    0.080583  0.682619

# %%
# Top N frequent itemsets
top_n = 10
top_itemsets = frequent_itemsets.sort_values('support', ascending=False).head(top_n)
plt.figure(figsize=(10,6))
sns.barplot(x='support', y=top_itemsets['itemsets'].astype(str), data=top_itemsets)
plt.title(f'Top {top_n} Frequent Itemsets (min_support={chosen_support})')
plt.xlabel('Support')
plt.ylabel('Itemset')
plt.show()

# Support vs Confidence Scatter Plot
plt.figure(figsize=(8,6))
sns.scatterplot(x='support', y='confidence', size='lift', data=rules, legend=False, alpha=0.7)
plt.title('Support vs Confidence of Association Rules')
plt.xlabel('Support')
plt.ylabel('Confidence')
plt.show()

# Lift Distribution Histogram
plt.figure(figsize=(8,6))
sns.histplot(rules['lift'], bins=20, kde=True)
plt.title('Distribution of Lift Values')
plt.xlabel('Lift')
plt.ylabel('Frequency')
# plt.show()
# Out:
# Text(0, 0.5, 'Frequency')

# %%
def recommend_items(items, rules, top_n=5):
    items_set = set(items)
    recommendations = {}

    for idx, row in rules.iterrows():
        antecedent = set(row['antecedents'])
        consequent = set(row['consequents'])

        # If all antecedent items are in the basket and none of the consequent items are
        if antecedent.issubset(items_set) and not consequent.issubset(items_set):
            for item in consequent:
                if item not in items_set:
                    # Keep the highest confidence for each recommended item
                    if item not in recommendations or recommendations[item] < row['confidence']:
                        recommendations[item] = row['confidence']

    # Sort recommendations by confidence, descending
    recommended_list = sorted(recommendations.items(), key=lambda x: x[1], reverse=True)
    return recommended_list[:top_n]

# Example usage:
# Suppose rules is your DataFrame of association rules
# and the basket contains 'frankfurter' and 'sausage'
basket = ['frankfurter', 'sausage']
top_recs = recommend_items(basket, rules, top_n=3)
print("Recommendations:", top_recs)
# Out:
# Recommendations: [('whole milk', 0.11605723370429252), ('other vegetables', 0.10723192019950124)]

# %%
basket = ['whole milk']
top_recs = recommend_items(basket, rules, top_n=3)
print("Recommendations:", top_recs)
# Out:
# Recommendations: []
